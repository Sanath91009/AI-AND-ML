# %%
#required libraries
import numpy as np
import pandas as pd
from sklearn.decomposition import NMF
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from nltk.corpus import stopwords

# %%
headlines=pd.read_csv('india-news-headlines.csv')
display(headlines)
# Out:
#          publish_date                 headline_category  \
# 0            20010101                        sports.wwe
# 1            20010102                           unknown
# 2            20010102                           unknown
# 3            20010102                           unknown
# 4            20010102                           unknown
# ...               ...                               ...
# 3297167      20200630                      gadgets-news
# 3297168      20200630     entertainment.hindi.bollywood
# 3297169      20200630     entertainment.hindi.bollywood
# 3297170      20200630     entertainment.hindi.bollywood
# 3297171      20200630  entertainment.telugu.movies.news
#
#                                              headline_text
# 0        win over cena satisfying but defeating underta...
# 1        Status quo will not be disturbed at Ayodhya; s...
# 2                      Fissures in Hurriyat over Pak visit
# 3                    America's unwanted heading for India?
# 4                       For bigwigs; it is destination Goa
# ...                                                    ...
# 3297167      why tiktok removed 1 65 crore videos in india
# 3297168  apurva asrani calls alia bhatts mother soni ra...
# 3297169  kangana ranaut gets a doll version of herself ...
# 3297170  meezaan jaffrey reminisces his childhood days ...
# 3297171  prabhas20 titled as radhe shyam prabhas and po...
#
# [3297172 rows x 3 columns]

# %%
headlines=headlines.drop(['publish_date'],axis=1)
headlines=headlines[:100000]

# %%
headlines
# Out:
#              headline_category  \
# 0                   sports.wwe
# 1                      unknown
# 2                      unknown
# 3                      unknown
# 4                      unknown
# ...                        ...
# 99995                  unknown
# 99996                    india
# 99997  business.india-business
# 99998                    india
# 99999                    india
#
#                                            headline_text
# 0      win over cena satisfying but defeating underta...
# 1      Status quo will not be disturbed at Ayodhya; s...
# 2                    Fissures in Hurriyat over Pak visit
# 3                  America's unwanted heading for India?
# 4                     For bigwigs; it is destination Goa
# ...                                                  ...
# 99995                     UN mission begins Africa visit
# 99996       BJP Gujarat unit meeting to discuss strategy
# 99997                   Forex reserves cross $55 billion
# 99998                        Two more killed in Vadodara
# 99999  NCP to vote against NDA govt in Lok Sabha: Sangma
#
# [100000 rows x 2 columns]

# %%
#we need to remove stop words in headlines
stop_w=stopwords.words('english')
total_words=[]
def remove_stop_words(x):
    words=x.split()
    new=[w for w in words if w not in stop_w]
    total_words.append([w for w in words if w not in stop_w and total_words])
    sentence=' '.join(new)
    return sentence
headlines["new_headlines"]=headlines["headline_text"].apply(lambda x : remove_stop_words(x))

# %%
headlines["new_headlines"]
# Out:
# 0        win cena satisfying defeating undertaker bigge...
# 1              Status quo disturbed Ayodhya; says Vajpayee
# 2                              Fissures Hurriyat Pak visit
# 3                        America's unwanted heading India?
# 4                             For bigwigs; destination Goa
#                                ...
# 99995                       UN mission begins Africa visit
# 99996            BJP Gujarat unit meeting discuss strategy
# 99997                     Forex reserves cross $55 billion
# 99998                                  Two killed Vadodara
# 99999                  NCP vote NDA govt Lok Sabha: Sangma
# Name: new_headlines, Length: 100000, dtype: object

# %%
total_words
# Out:
# [[],
#  ['Status', 'quo', 'disturbed', 'Ayodhya;', 'says', 'Vajpayee'],
#  ['Fissures', 'Hurriyat', 'Pak', 'visit'],
#  ["America's", 'unwanted', 'heading', 'India?'],
#  ['For', 'bigwigs;', 'destination', 'Goa'],
#  ['Extra', 'buses', 'clear', 'tourist', 'traffic'],
#  ['Dilute', 'power', 'transfers;', 'says', 'Riberio'],
#  ['Focus', 'shifts', 'teaching', 'Hindi'],
#  ['IT', 'become', 'compulsory', 'schools'],
#  ['Move', 'stop', 'freedom', "fighters'", 'pension', 'flayed'],
#  ['Gilani', 'claims', 'applied', 'passport', '2', 'years', 'ago'],
#  ['Parivar', 'dismisses', "PM's", 'warning'],
#  ['India;', 'Pak', 'exchange', 'lists', 'N-plants'],
#  ['Will', "Qureshi's", 'return', 'really', 'help', 'govt?'],
#  ["PM's", 'tacit', 'message:', 'Put', 'Ram', 'tample', 'hold'],
#  ['Text', 'Prime', "Minister's", 'article'],
#  ['NCW', 'focus', 'violence', 'women'],
#  ["BBC's", 'reality', 'TV', 'focus', 'AIIMS'],
#  ['Jaitley', 'firm', 'legal', 'reforms'],
#  ['Hoshangabad', 'farmers', 'enough', 'water'],
#  ['BJP', 'jumps', 'rail', 'track', 'conversion', 'issue'],
#  ["America's", 'unwanted', 'heading', 'India?'],
#  ['State', 'may', 'take', 'AP', 'court', 'Krishna'],
#  ['This', 'official', 'sued', 'briber'],
#  ['Park', 'turns', 'temple', 'compound', 'residents', 'watch'],
#  ['Moves', 'afoot', 'evict', 'squatters', 'Urban', 'dist'],
#  ['Mafia', 'calls', 'shots', 'Gandhinagar'],
#  ['Status', 'quo', 'disturbed', 'Ayodhya;', 'says', 'Vajpayee'],
#  ['Fissures', 'Hurriyat', 'Pak', 'visit'],
#  ["America's", 'unwanted', 'heading', 'India?'],
#  ['For', 'bigwigs;', 'destination', 'Goa'],
#  ['Extra', 'buses', 'clear', 'tourist', 'traffic'],
#  ['Dilute', 'power', 'transfers;', 'says', 'Riberio'],
#  ['Focus', 'shifts', 'teaching', 'Hindi'],
#  ['IT', 'become', 'compulsory', 'schools'],
#  ['Move', 'stop', 'freedom', "fighters'", 'pension', 'flayed'],
#  ['Gilani', 'claims', 'applied', 'passport', '2', 'years', 'ago'],
#  ['Parivar', 'dismisses', "PM's", 'warning'],
#  ['India;', 'Pak', 'exchange', 'lists', 'N-plants'],
#  ['Will', "Qureshi's", 'return', 'really', 'help', 'govt?'],
#  ["PM's", 'tacit', 'message:', 'Put', 'Ram', 'tample', 'hold'],
#  ['Text', 'Prime', "Minister's", 'article'],
#  ['NCW', 'focus', 'violence', 'women'],
#  ["BBC's", 'reality', 'TV', 'focus', 'AIIMS'],
#  ['Jaitley', 'firm', 'legal', 'reforms'],
#  ['Hoshangabad', 'farmers', 'enough', 'water'],
#  ['BJP', 'jumps', 'rail', 'track', 'conversion', 'issue'],
#  ["America's", 'unwanted', 'heading', 'India?'],
#  ['State', 'may', 'take', 'AP', 'court', 'Krishna'],
#  ['This', 'official', 'sued', 'briber'],
#  ['Park', 'turns', 'temple', 'compound', 'residents', 'watch'],
#  ['Moves', 'afoot', 'evict', 'squatters', 'Urban', 'dist'],
#  ['Mafia', 'calls', 'shots', 'Gandhinagar'],
#  ['Come', 'Nandi', 'Hills...and', 'fly'],
#  ['HAL', 'approached', 'super', 'jumbo', 'project'],
#  ['Nagathihalli', 'returns', 'Preethiya', 'Hudugi'],
#  ['Fashion', 'future'],
#  ['Promises', 'keep'],
#  ['Home', 'holistic', 'science'],
#  ['A', 'noisy', 'effort', 'spruce', 'Commercial', 'Street'],
#  ['The', 'best', 'music', 'year'],
#  ['Redemption', 'night;', 'amid', 'rock'],
#  ['Consul', 'back', 'month-long', 'leave'],
#  ['Bomb', 'hoax', 'triggers', 'panic', 'Canara', 'Bank'],
#  ['Petition', "ministers'", 'assets', 'dismissed'],
#  ['He', 'beat', 'polio;', 'truck', "driver's", 'life'],
#  ['Destroying', 'myths', 'doubts', 'sexuality'],
#  ['Planning', 'Dept', 'seeks', 'Rs', '350', 'crore'],
#  ['More', 'engg', 'colleges', 'needed', 'state:', 'Govt'],
#  ['Auto', "driver's", 'murder:', '4', 'held'],
#  ['Meet', 'held', 'cashew', 'crop', 'forecasting'],
#  ['Awareness', 'rally', 'AIDS', 'today'],
#  ['Record', 'power', 'generation', 'RTPS'],
#  ['Move', 'stop', 'freedom', "fighters'", 'pension', 'flayed'],
#  ['Snags', 'delay', 'digital', 'maps', 'city'],
#  ['Making', 'education', "people's", 'movement'],
#  ['Murder', 'spoils', '2001', 'party', 'Dharwad'],
#  ['Now', 'website', 'seer'],
#  ['Akki-Alur', 'Ranebennur', 'peaceful'],
#  ['Weekly', 'editor', 'resorts', 'hunger', 'strike'],
#  ['Bickering', 'cost', 'Dal(S)', 'seats;', 'admits', 'Gowda'],
#  ['BJP', 'block', 'traffic', 'statewide', 'Jan', '6'],
#  ['Dr', 'Patwardhan', 'felicitated'],
#  ['Lingambudhi', 'turned', 'bird', 'sanctuary'],
#  ['Cactus', 'made', 'Guinness', 'dying'],
#  ['VIPs', 'suffer', 'power', 'supply', 'stopped', 'govt', 'guest', 'houses'],
#  ['Raju', 'Chacha'],
#  ['Powerless', 'north', 'India', 'gropes', 'dark'],
#  ['Think', 'again;', 'Laxman', 'tells', 'Sangh', 'Parivar'],
#  ['Hurriyat', 'undecided', 'team', 'Pakistan'],
#  ['Vajpayee', 'wants', 'put', 'reforms', 'fast', 'track'],
#  ['Stephen', 'Hawking', 'keeps', 'date', 'Mumbai'],
#  ['Anti-Hrithik', 'anti-hopelessness'],
#  ['Govt', 'plans', 'stadium', 'near', 'Panaji'],
#  ['BJP', 'volte', 'face', 'casinos:', 'Cong'],
#  ['3', 'watershed', 'projects', 'anvil'],
#  ['No', 'report', 'yet', 'fire', 'Udyog', 'Bhavan'],
#  ['He', 'king', "'five", "star'", 'industry'],
#  ['Petrol', 'pump', 'sealed', 'selling', 'adulterated', 'fuel'],
#  ['Milk', 'price', 'Rs', '1', 'per', 'litre'],
#  ['Congress', 'House', 'no-smoking', 'zone'],
#  ['Rural', 'weightage:', 'Govt', 'reassures', 'Governor'],
#  ['Bride', 'gets', 'honeymoon', 'surprise:', 'Chopper', 'ride'],
#  ['Is', 'hangover', 'sign', 'alcoholicism?'],
#  ['Almatti:', 'AP', 'wait', 'watch'],
#  ['10-year-old', 'girl', 'missing'],
#  ['Hear', 'messages', 'heart'],
#  ['Dance', 'like', "one's", 'watching'],
#  ['From', 'reel', 'love', 'real', 'love'],
#  ['Power', 'row:', 'Bribe', 'attempt', 'charge', 'denied'],
#  ["Lakshamma's", 'cry', 'help', 'heard'],
#  ["It's", 'shopping', 'time', 'newborn'],
#  ['Con', 'games', 'catwalk'],
#  ['They', 'help', 'us'],
#  ['These', 'noisy', 'spots', 'hurting', 'ears'],
#  ['Flat', 'tyres;', 'flat', 'music', 'famous', 'faces'],
#  ['Yogananda', 'birth', 'anniversary', 'fete', 'Dec', '5'],
#  ['Tumkur', 'gets', '243', 'borewells'],
#  ['Over', '2000', 'workers', 'hit', 'lockout'],
#  ['Child', 'project', 'officer', 'held', 'fraud'],
#  ['BCC', 'holds', 'talks', 'budget'],
#  ['Skybus', 'metro', 'trains', 'agenda'],
#  ['A', 'disciple', 'awaits', 'miracle', 'Goddess'],
#  ['TOI', 'scribe', 'among', 'Press', 'Academy', 'awardees'],
#  ['Talent', 'Search', 'exams', 'April', '29'],
#  ['Ban', 'orders', 'extended', 'Ranebennur'],
#  ['Army', 'turns', 'HAL', 'Lancer', 'supply'],
#  ["'Devdas':", 'Jinxed?'],
#  ['The', 'string', 'pulled', 'Stephen', 'Hawking', 'India'],
#  ['Vajpayee', 'gives', 'big', 'push', 'tech', 'education;', 'R&D'],
#  ['Norms', 'private', 'role', 'banking', 'tightened'],
#  ['A', 'Maha', 'Kumbh', 'media', 'players'],
#  ['Net', 'lottery:', 'A', 'winner', 'sucker?'],
#  ['Us', "PM's", 'Musings'],
#  ['Milosevic', 'charged', "'abuse", "office'"],
#  ['Tabu:', 'Bar', 'Bar', 'Dekho'],
#  ['Anupam', 'Kher:', 'Sliver', 'Spoon!'],
#  ['Aftab', 'Shivdasani:', 'Career', 'Cares!'],
#  ['Court', 'reserves', 'judgment', 'custody', "Ilyasi's", 'daughter'],
#  ['A', 'museum', 'far', 'madding', 'crowds'],
#  ['Bangla', 'Oppn', 'leader', 'issues', "'fatwa'", 'judges'],
#  ['Hawking', 'set', 'inspire', 'science', 'glitterati'],
#  ['Mission', 'technology', 'education;', 'funds', 'R&D'],
#  ['Mental', 'illness', 'pass', 'parent', 'child'],
#  ['Cholera', 'outbreak', 'source', 'traced'],
#  ['Mathematics', 'permeates', 'human', 'civilisation'],
#  ['Bangla', 'Oppn', 'leader', 'issues', "'fatwa'", 'judges'],
#  ['Bangladesh', 'govt', 'asks', 'Hamoodur', 'Rahman', 'report'],
#  ['Bangladesh', "'scrutinising'", "citizen's", 'death', 'US', 'embassy'],
#  ['Claire', 'Danes', 'inks', 'star', "'It's", 'About', "Love'"],
#  ['Hollywood', 'posts', 'record', '9th', 'year', 'box', 'office', 'gains'],
#  ['Akashdeep:', 'Ghaath', 'Ka', 'Saath!'],
#  ['Great', 'loss', 'Indian', 'racing'],
#  ['The', 'saga', 'Usha', 'Stud', 'Farm'],
#  ['Red', 'Radior', 'wins', 'Victory', 'Zone', 'Cup'],
#  ['Race', 'put'],
#  ['Cyril', 'sends', 'Byron', 'Black', 'packing'],
#  ['Dent', 'fastest', 'serve', 'Chennai', 'meet'],
#  ['Basu', 'gives', 'call', 'stop', 'infighting'],
#  ['Violence', 'mar', "Mamata's", 'meeting', 'Midnapore'],
#  ['The', 'string', 'pulled', 'Stephen', 'Hawking', 'India'],
#  ['Norms', 'private', 'role', 'banking', 'tightened'],
#  ['Net', 'lottery:', 'A', 'winner', 'sucker?'],
#  ['Us', "PM's", 'Musings'],
#  ['Milosevic', 'charged', "'abuse", "office'"],
#  ['Tabu:', 'Bar', 'Bar', 'Dekho'],
#  ['Anupam', 'Kher:', 'Sliver', 'Spoon!'],
#  ['Court', 'reserves', 'judgment', 'custody', "Ilyasi's", 'daughter'],
#  ['A', 'museum', 'far', 'madding', 'crowds'],
#  ['Bangla', 'Oppn', 'leader', 'issues', "'fatwa'", 'judges'],
#  ['Court', 'reserves', 'judgment', 'custody', "Ilyasi's", 'daughter'],
#  ['String', 'theory', 'set', 'become', 'one', 'hottest', 'pieces', 'physics'],
#  ['Hawking', 'set', 'inspire', 'science', 'glitterati'],
#  ['Mission', 'technology', 'education;', 'funds', 'R&D'],
#  ['Mission', 'technology', 'education;', 'funds', 'R&D'],
#  ['Mental', 'illness', 'pass', 'parent', 'child'],
#  ['Cholera', 'outbreak', 'source', 'traced'],
#  ['Mathematics', 'permeates', 'human', 'civilisation'],
#  ['The', 'string', 'pulled', 'Stephen', 'Hawking', 'India'],
#  ['Vajpayee', 'gives', 'big', 'push', 'tech', 'education;', 'R&D'],
#  ['Norms', 'private', 'role', 'banking', 'tightened'],
#  ['A', 'Maha', 'Kumbh', 'media', 'players'],
#  ['Net', 'lottery:', 'A', 'winner', 'sucker?'],
#  ['Us', "PM's", 'Musings'],
#  ['Milosevic', 'charged', "'abuse", "office'"],
#  ['Tabu:', 'Bar', 'Bar', 'Dekho'],
#  ['Anupam', 'Kher:', 'Sliver', 'Spoon!'],
#  ['Aftab', 'Shivdasani:', 'Career', 'Cares!'],
#  ['Court', 'reserves', 'judgment', 'custody', "Ilyasi's", 'daughter'],
#  ['A', 'museum', 'far', 'madding', 'crowds'],
#  ['Four', 'Iranians', 'admit', 'role', 'serial', 'murders'],
#  ['Bangla', 'Oppn', 'leader', 'issues', "'fatwa'", 'judges'],
#  ['String', 'theory', 'set', 'become', 'one', 'hottest', 'pieces', 'physics'],
#  ['Hawking', 'set', 'inspire', 'science', 'glitterati'],
#  ['Mission', 'technology', 'education;', 'funds', 'R&D'],
#  ['Mental', 'illness', 'pass', 'parent', 'child'],
#  ['Cholera', 'outbreak', 'source', 'traced'],
#  ['Mathematics', 'permeates', 'human', 'civilisation'],
#  ['Bangla', 'Oppn', 'leader', 'issues', "'fatwa'", 'judges'],
#  ['Bangladesh', 'govt', 'asks', 'Hamoodur', 'Rahman', 'report'],
#  ['Bangladesh', "'scrutinising'", "citizen's", 'death', 'US', 'embassy'],
#  ['Hollywood', 'posts', 'record', '9th', 'year', 'box', 'office', 'gains'],
#  ['Great', 'loss', 'Indian', 'racing'],
#  ['The', 'saga', 'Usha', 'Stud', 'Farm'],
#  ['Red', 'Radior', 'wins', 'Victory', 'Zone', 'Cup'],
#  ['Race', 'put'],
#  ['Basu', 'gives', 'call', 'stop', 'infighting'],
#  ['Violence', 'mar', "Mamata's", 'meeting', 'Midnapore'],
#  ['CPT', 'new', 'pilot', 'system', 'Jan', '15'],
#  ['Film', 'industry', 'concerned', 'piracy'],
#  ['City', 'drainage', 'system', 'modernised'],
#  ['Keeping', 'Gandhian', 'dream', 'alive'],
#  ['An', 'archaeologist', 'par', 'excellence'],
#  ['Education', 'body', 'overshoots', 'self-imposed', 'deadline'],
#  ['PIL', 'urges', 'seek', 'flood', 'relief', 'UN'],
#  ['Sen', 'urges', 'country', 'exploit', 'tourism', 'potential'],
#  ['CMC', 'issue', 'notice', 'builder'],
#  ['World', 'govt', 'touted', 'solution', 'crises'],
#  ['ASI', 'team', 'digs', 'part', 'Fatehpur', 'Sikri'],
#  ['Lara', 'joins', 'elite', 'club'],
#  ['Cullinan', 'hits', 'fourth', 'Newlands', 'hundred'],
#  ['Cronje', 'case', 'behind', 'low', 'cricket', 'match', 'attendance'],
#  ['Indian', 'refusal', 'cost', 'PCB', '2.4', 'cr'],
#  ['Das', 'ready', 'face', 'short-pitch', 'stuff'],
#  ['Haldipur;', 'Lahiri', 'good', 'stand'],
#  ['DU', 'North', 'Zone', 'inter-varsity', 'cricket', 'champions'],
#  ['Kolkata', 'gears', 'Millennium', 'Cup'],
#  ['Right', 'choice', 'key;', 'says', 'Iranian', 'coach'],
#  ['Rajasthan', 'lose', 'lead', 'match'],
#  ['Hockey', 'hopes', 'rest', 'flowerin', 'talent'],
#  ['Anand', 'may', 'get', 'Padmabhushan'],
#  ['Emotion-choked', 'Chennai', 'showers', 'love', 'Anand'],
#  ['Close', 'battle', 'Mahindra', 'Golfer;', '2001'],
#  ['Indian', 'Blues', 'good', 'start'],
#  ['Ramgarh', 'beat', 'Royal', 'Kashmir', 'Hanut', 'Cup', 'polo'],
#  ['Anand', 'may', 'get', 'Padmabhushan'],
#  ['Cullinan', 'hits', 'fourth', 'Newlands', 'hundred'],
#  ['Ex-mayor', 'takes', 'cudgels', 'Kothrud', 'garbage', 'depot'],
#  ['India', 'IT', 'superpower'],
#  ['A', 'clean', 'sweep'],
#  ['The', 'Sphinx', 'act'],
#  ['Giving', 'audio-video', 'education', 'cutting', 'edge'],
#  ['Govt', 'orders', 'study', 'river', 'diversion'],
#  ['Govt', 'bears', 'burden', 'VIPs', 'throng', 'Goa'],
#  ['Goa', 'told', 'start', 'quick-growth', 'coconut', 'project'],
#  ['Experts', 'discuss', 'horticulture', 'development'],
#  ['5', 'acquitted', 'trespassing', 'case'],
#  ['Development', 'horticulture', 'stressed'],
#  ['New', 'office-bearers', 'ICSI'],
#  ['CM', 'review', 'security', 'Premji;', 'Murthy'],
#  ['Govt', 'allots', 'UKP', 'project', 'KPC'],
#  ['Star', 'hotels', 'city', 'get', 'tech-savvy'],
#  ['When', 'principals', 'wed'],
#  ['Misbehaving', 'conductors', 'face', 'action'],
#  ['Pubs', 'watch', 'violence'],
#  ['Celestial', 'show', 'awaits', 'aircraft', 'lovers'],
#  ['Kannada', 'organisations', 'oppose', 'felicitating', 'Nedumaran'],
#  ['Civic', 'polls:', 'Minister', 'refutes', 'BJP', 'charges'],
#  ['Oh;', 'black', '&', 'white', 'magic!'],
#  ['No', 'clue', 'kidnapped', 'boy'],
#  ['New', 'year', 'hash:', 'They', 'paid', 'Rs', '18;000;', 'went', 'hungry'],
#  ['5;000', 'anganwadis', 'get', 'buildings'],
#  ['Cops', 'shoot', 'sandalwood', 'smugglers;', 'nab', 'one'],
#  ['Tribute-paying', 'ritual', 'Patel', 'today'],
#  ['A', 'life', 'snuffed', 'needlessly'],
#  ['PM', 'arriving', '2-day', 'visit'],
#  ['Make', 'mysterious', 'kidnap', 'drama', 'secret', 'public'],
#  ['Pollution', 'makes', 'residents', 'see', 'red'],
#  ['Behind', 'walls;', 'celebration', 'time'],
#  ['Corporate', 'cricket', 'lot', 'scope'],
#  ['An', 'art', 'gallery', 'underprivileged'],
#  ['Annual', 'Infant', 'Jesus', 'feast', 'Jan', '14'],
#  ['Ex-Karnataka', 'HC', 'judge', 'visits', 'Bahrain'],
#  ['Dudhwa', 'tiger', 'died', 'starvation;', 'poisoning'],
#  ['Three', 'race', 'chief', "secy's", 'post'],
#  ["Druggists'", 'stir', 'leads', 'shortage', 'medicines'],
#  ['Car', 'dealers', 'caught', 'Bihar', 'sales', 'tax', 'ruling'],
#  ['Space', 'Cowboys'],
#  ["He's", 'inscrutable'],
#  ['DPCC', 'stages', 'Nyay', 'rally'],
#  ['Unbreakable'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ["Hawkings'", 'day'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ['Easy', 'drugs', 'raves', 'keep', 'Goa', 'hot', 'tourist', 'circuit'],
#  ['CM', 'defends', 'grant', 'Chaturang'],
#  ['Faleiro', 'vows', 'fight', 'common', 'cadre', 'proposal'],
#  ['Sawant', 'questions', 'casino', 'licences'],
#  ['MPT', 'posts', 'good', 'show', '2000'],
#  ['Ex-GPCC', 'chief', 'separate', 'cadre'],
#  ['Meeting', 'review', 'anti-defection', 'law'],
#  ['Telecom', 'team', 'win', 'play', 'contest'],
#  ['Guala', 'Closures', 'bags', 'ISO', '9002', 'certificate'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Indian', 'American', 'boy', 'confesses', "parents'", 'murder'],
#  ['Anti-immigration', 'think-tank', 'berates', 'Clinton', 'regime'],
#  ['Sikh', 'teacher', 'guilty', 'assaulting', 'student'],
#  ['Australia;',
#   'New',
#   'Zealand',
#   'urged',
#   'accept',
#   'Indo-Fijian',
#   'refugees'],
#  ['If', 'Rabuka', 'go', 'free;', 'us:', 'Speight', 'partner'],
#  ['Tailor', "Sam's", 'famous', 'clientele'],
#  ['Malaysian', 'medics', 'testify', "demonstrators'", 'injuries'],
#  ['Philippine', 'soldiers', 'arrest', 'bombing', 'suspects'],
#  ['Chinese', 'stranded', 'Dhaka', 'repatriated'],
#  ["It's", 'long', 'haul', 'yet', 'LCA'],
#  ['Captain', 'Courageous', 'says', 'dream', 'come', 'true'],
#  ['LCA', 'good', 'enough', 'next', '45', 'yrs'],
#  ['LCA', 'top', 'avionics;', 'strike', 'capability'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ["Hawkings'", 'day'],
#  ['Easy', 'drugs', 'raves', 'keep', 'Goa', 'hot', 'tourist', 'circuit'],
#  ['CM', 'defends', 'grant', 'Chaturang'],
#  ['Faleiro', 'vows', 'fight', 'common', 'cadre', 'proposal'],
#  ['Sawant', 'questions', 'casino', 'licences'],
#  ['MPT', 'posts', 'good', 'show', '2000'],
#  ['Ex-GPCC', 'chief', 'separate', 'cadre'],
#  ['Meeting', 'review', 'anti-defection', 'law'],
#  ['Telecom', 'team', 'win', 'play', 'contest'],
#  ['Guala', 'Closures', 'bags', 'ISO', '9002', 'certificate'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Indian', 'American', 'boy', 'confesses', "parents'", 'murder'],
#  ['Indian', 'American', 'boy', 'confesses', "parents'", 'murder'],
#  ['Anti-immigration', 'think-tank', 'berates', 'Clinton', 'regime'],
#  ['Sikh', 'teacher', 'guilty', 'assaulting', 'student'],
#  ['Australia;',
#   'New',
#   'Zealand',
#   'urged',
#   'accept',
#   'Indo-Fijian',
#   'refugees'],
#  ['If', 'Rabuka', 'go', 'free;', 'us:', 'Speight', 'partner'],
#  ['Tailor', "Sam's", 'famous', 'clientele'],
#  ['Malaysian', 'medics', 'testify', "demonstrators'", 'injuries'],
#  ['Philippine', 'soldiers', 'arrest', 'bombing', 'suspects'],
#  ['Chinese', 'stranded', 'Dhaka', 'repatriated'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ["It's", 'long', 'haul', 'yet', 'LCA'],
#  ['Captain', 'Courageous', 'says', 'dream', 'come', 'true'],
#  ['LCA', 'good', 'enough', 'next', '45', 'yrs'],
#  ['LCA', 'top', 'avionics;', 'strike', 'capability'],
#  ['CM', 'asks', 'KPTC', 'keep', 'power', 'tariff', 'hike', 'abeyance'],
#  ['Gowda', 'Hegde', 'share', 'dais;', 'fail', 'talk'],
#  ['This', 'cactus', 'set', 'break', 'records'],
#  ['Function', "can't", 'stopped:', 'Kharge'],
#  ['Think', 'twice', 'make', 'wish'],
#  ['LCA:', 'Best', 'weapon', 'system', 'close', 'combat'],
#  ['LCA', 'test', 'flight', 'puts', 'India', 'exclusive', 'club'],
#  ['A', 'dream-come-true', 'LCA', 'pilot'],
#  ['Avionics', 'provides', 'multi-role', 'capability', 'LCA'],
#  ['Hoax', 'bomb', 'call', 'sends', 'family', 'tizzy'],
#  ['Govt', 'order', 'dismantling', 'Hampi', 'bridge', 'stayed'],
#  ['Principals', 'PU', 'colleges', 'meet', 'Jan.', '7'],
#  ['CM', 'meets', 'Sonia', 'airport'],
#  ['Tributes', 'paid', 'Patel'],
#  ['I', 'great', 'fan', 'Sridevi:', 'Prema'],
#  ['This', 'chef', 'knows', 'yin', 'yang'],
#  ['Wait;', 'wait...', 'bus', 'never', 'comes'],
#  ['Taal', 'se', 'taal', 'mila'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ["Hawkings'", 'day'],
#  ['Easy', 'drugs', 'raves', 'keep', 'Goa', 'hot', 'tourist', 'circuit'],
#  ['CM', 'defends', 'grant', 'Chaturang'],
#  ['Sawant', 'questions', 'casino', 'licences'],
#  ['MPT', 'posts', 'good', 'show', '2000'],
#  ['Ex-GPCC', 'chief', 'separate', 'cadre'],
#  ['Meeting', 'review', 'anti-defection', 'law'],
#  ['Guala', 'Closures', 'bags', 'ISO', '9002', 'certificate'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Indian', 'American', 'boy', 'confesses', "parents'", 'murder'],
#  ['Anti-immigration', 'think-tank', 'berates', 'Clinton', 'regime'],
#  ['Sikh', 'teacher', 'guilty', 'assaulting', 'student'],
#  ['Australia;',
#   'New',
#   'Zealand',
#   'urged',
#   'accept',
#   'Indo-Fijian',
#   'refugees'],
#  ['If', 'Rabuka', 'go', 'free;', 'us:', 'Speight', 'partner'],
#  ['Tailor', "Sam's", 'famous', 'clientele'],
#  ['Malaysian', 'medics', 'testify', "demonstrators'", 'injuries'],
#  ['Philippine', 'soldiers', 'arrest', 'bombing', 'suspects'],
#  ['Chinese', 'stranded', 'Dhaka', 'repatriated'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ["It's", 'long', 'haul', 'yet', 'LCA'],
#  ['Captain', 'Courageous', 'says', 'dream', 'come', 'true'],
#  ['LCA', 'good', 'enough', 'next', '45', 'yrs'],
#  ['LCA', 'top', 'avionics;', 'strike', 'capability'],
#  ['CM', 'asks', 'KPTC', 'keep', 'power', 'tariff', 'hike', 'abeyance'],
#  ['Gowda', 'Hegde', 'share', 'dais;', 'fail', 'talk'],
#  ['This', 'cactus', 'set', 'break', 'records'],
#  ['Function', "can't", 'stopped:', 'Kharge'],
#  ['Think', 'twice', 'make', 'wish'],
#  ['LCA:', 'Best', 'weapon', 'system', 'close', 'combat'],
#  ['LCA', 'aircraft', 'next', '45', 'years'],
#  ['LCA', 'test', 'flight', 'puts', 'India', 'exclusive', 'club'],
#  ['A', 'dream-come-true', 'LCA', 'pilot'],
#  ['Avionics', 'provides', 'multi-role', 'capability', 'LCA'],
#  ['Hoax', 'bomb', 'call', 'sends', 'family', 'tizzy'],
#  ['Govt', 'order', 'dismantling', 'Hampi', 'bridge', 'stayed'],
#  ['Principals', 'PU', 'colleges', 'meet', 'Jan.', '7'],
#  ['CM', 'meets', 'Sonia', 'airport'],
#  ['Tributes', 'paid', 'Patel'],
#  ['I', 'great', 'fan', 'Sridevi:', 'Prema'],
#  ['This', 'chef', 'knows', 'yin', 'yang'],
#  ['Wait;', 'wait...', 'bus', 'never', 'comes'],
#  ['Taal', 'se', 'taal', 'mila'],
#  ['Mahalakshmi', 'Layout:', 'Crumbling', 'past;', 'rapid', 'growth'],
#  ["'We're", 'waiting', 'people', "money'"],
#  ['An', 'actress', 'many', 'things', 'besides'],
#  ['Mobile', 'phone', 'fun', 'machine'],
#  ['Time', 'bow', '14', 'top', 'bureaucrats'],
#  ['Silk', 'sexy', 'year'],
#  ['Seeds', 'firm', 'condemns', 'hooliganism'],
#  ['Nepal', 'allow', 'anti-India', 'activities:', 'Envoy'],
#  ['MP', 'best', 'forest', 'development:', 'Centre'],
#  ['Light', 'combat', 'craft', 'takes', 'India', 'club', 'class'],
#  ["Hawkings'", 'day'],
#  ['Ex-GPCC', 'chief', 'separate', 'cadre'],
#  ['Meeting', 'review', 'anti-defection', 'law'],
#  ['Telecom', 'team', 'win', 'play', 'contest'],
#  ['Guala', 'Closures', 'bags', 'ISO', '9002', 'certificate'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Bush', 'names', 'Lindsey', 'top', 'economic', 'aide'],
#  ['Indian', 'American', 'boy', 'confesses', "parents'", 'murder'],
#  ['Anti-immigration', 'think-tank', 'berates', 'Clinton', 'regime'],
#  ['Sikh', 'teacher', 'guilty', 'assaulting', 'student'],
#  ['Australia;',
#   'New',
#   'Zealand',
#   'urged',
#   'accept',
#   'Indo-Fijian',
#   'refugees'],
#  ['Muslim', 'body', 'rules', 'talks', 'Ayodhya'],
#  ['Bajrang', 'Dal', 'blows', 'hot;', 'cold'],
#  ['Vajpayee', 'rejects', "Nitish's", 'resignation'],
#  ['PM', 'taps', 'diaspora', 'realise', 'Indian', 'ambition'],
#  ['India', 'cagey', 'food', 'imports'],
#  ['US', 'leggy', 'chicks', 'come', 'hordes'],
#  ['Microsoft;', 'Intel', 'line', 'top-end', 'products', 'electronics', 'show'],
#  ['Khosla', 'among', "Upside's", '25', 'people', 'watch', '2001'],
#  ['Spending', 'Net', 'projects', 'may', 'hit'],
#  ['British',
#   'doctor',
#   'may',
#   'worst',
#   'mass',
#   'murderer',
#   'modern',
#   'history'],
#  ['British', 'judge', 'reveals', 'threats', 'racists'],
#  ['Clinton', 'urges', 'US', 'Congress', 'ratify', 'CTBT'],
#  ['Blind', 'climber', 'scale', 'Mt.', 'Everest'],
#  ['Does', 'American', 'TV', 'realism', 'overdose?'],
#  ['Banking', 'community', 'must', 'chalk', 'new', 'system:', 'Jalan'],
#  ['Delhi', 'host', 'India-EU', 'working', 'group', 'meeting', 'IT'],
#  ['PNB', 'raises', 'rates'],
#  ['Are', 'green', 'activists', 'new', 'imperialists'],
#  ['Muslim', 'body', 'rules', 'talks', 'Ayodhya'],
#  ['Bajrang', 'Dal', 'blows', 'hot;', 'cold'],
#  ['Vajpayee', 'rejects', "Nitish's", 'resignation'],
#  ['PM', 'taps', 'diaspora', 'realise', 'Indian', 'ambition'],
#  ['India', 'cagey', 'food', 'imports'],
#  ['US', 'leggy', 'chicks', 'come', 'hordes'],
#  ['Microsoft;', 'Intel', 'line', 'top-end', 'products', 'electronics', 'show'],
#  ['Khosla', 'among', "Upside's", '25', 'people', 'watch', '2001'],
#  ['Spending', 'Net', 'projects', 'may', 'hit'],
#  ['British',
#   'doctor',
#   'may',
#   'worst',
#   'mass',
#   'murderer',
#   'modern',
#   'history'],
#  ['British', 'judge', 'reveals', 'threats', 'racists'],
#  ['Clinton', 'urges', 'US', 'Congress', 'ratify', 'CTBT'],
#  ['Blind', 'climber', 'scale', 'Mt.', 'Everest'],
#  ['Does', 'American', 'TV', 'realism', 'overdose?'],
#  ['Banking', 'community', 'must', 'chalk', 'new', 'system:', 'Jalan'],
#  ['Delhi', 'host', 'India-EU', 'working', 'group', 'meeting', 'IT'],
#  ['Are', 'green', 'activists', 'new', 'imperialists'],
#  ['Asian', 'auto', 'firms', 'bullish', 'US', 'market'],
#  ['Clinton', 'urges', 'US', 'Congress', 'ratify', 'CTBT'],
#  ['US', 'gets', 'first', 'multicultural', 'cabinet'],
#  ['Indian', 'American', 'couple', 'sentenced', 'injuries', 'child'],
#  ['Mumbai', 'firm', 'sentenced', 'US'],
#  ['Parsi', 'men', 'failed', 'women'],
#  ['Does', 'American', 'TV', 'realism', 'overdose?'],
#  ['Transit;', 'port', 'use', 'top', 'talks', 'Nepal', "minister's", 'visit'],
#  ['Kuldip', "Sharma's", 'exit', 'lead', 'sea', 'change', 'policing'],
#  ['WREB', 'warns', 'SEBs', 'north-like', 'tripping'],
#  ['Chaotic', 'traffic', 'Mehsana:', 'Authorities', 'washed', 'hands'],
#  ['MSU', 'gears', 'NAAC', 'visit;', 'expects', 'five-star', 'rating'],
#  ['Residents', 'invested', 'bore-wells'],
#  ['Need', 'farmers', 'become', 'professionals:', 'Expert'],
#  ['Aamir', 'Khan:', "'Lagaan'", 'ko', 'zabaan'],
#  ['Rajkumar', 'Santoshi:', 'Khan', 'pe', 'khan'],
#  ['Kamal', 'Haasan:', 'Hey', '(Thenali)', 'Ram'],
#  ['Darshans', 'show', 'Bollywood', 'way', 'financial', 'woes'],
#  ['Latest', 'Hrithik', 'movie', 'could', 'make', 'Canberra', 'hit'],
#  ['The', 'Bali', 'beat', 'goes', 'beyond', 'bhangra'],
#  ['Tops', 'trousers;', "they're", 'going', 'gold!'],
#  ['Aamir', 'Khan:', "'Lagaan'", 'ko', 'zabaan'],
#  ['Rajkumar', 'Santoshi:', 'Khan', 'pe', 'khan'],
#  ['Kamal', 'Haasan:', 'Hey', '(Thenali)', 'Ram'],
#  ['Darshans', 'show', 'Bollywood', 'way', 'financial', 'woes'],
#  ['German', 'TV', 'admits', 'millionaire', 'show', 'sham'],
#  ['Parliament', 'suggests', 'resignation', 'TV', 'official'],
#  ['Traffic', 'lights'],
#  ['Just', 'one', 'faces'],
#  ['Steve', 'Waugh', 'looks', 'forward', 'Indian', 'summer'],
#  ['Strong', 'comeback', 'Shane', 'Warne'],
#  ['Cricket', 'board', 'chief', 'means', 'business'],
#  ['Sangh', 'Parivar;', 'Babri', 'panel', 'ante'],
#  ['Frontrunner', 'key', 'US', 'post', 'seen', 'Pak', 'tilt'],
#  ['Muslims', 'see', 'red', 'Coke', 'logo'],
#  ['Move', 'Nepal;', 'Casino', 'Goa'],
#  ['Merit', 'Calling'],
#  ['Closures', 'putting', 'financial', 'strain', 'Delhi', 'Govt'],
#  ['42', 'units', 'sealed', 'phase-II', 'operation', 'closure'],
#  ['Special', 'trains', 'Kumbh', 'Mela'],
#  ['CPM', 'survey', 'units'],
#  ['NIEPA', 'meet', 'discuss', 'issue', 're-employing', 'retired', 'teachers'],
#  ['Such', 'long', 'journey', 'green', 'dispenser'],
#  ['Woman', 'fighting', 'life', "'quack'", 'performed', 'MTP'],
#  ['Cold', 'weather', 'puts', 'strain', 'people', 'weak', 'hearts'],
#  ['Secrecy', 'place', 'democracy;', 'says', 'Sorabjee'],
#  ['On', 'hitlist', 'polluting', 'units'],
#  ['Driver', 'makes', 'cash', "employer's", 'Zen'],
#  ['Rs', '25;000', 'compensation', '10-yr-old', 'domestic', 'help'],
#  ['What', 'one', 'backache', "'epidemic'"],
#  ['Criminals', 'beat', 'family', 'iron', 'rods'],
#  ['Three', 'held', 'stealing', 'power'],
#  ['Road', 'accident', 'toll', 'Noida', '130', 'last', 'year'],
#  ['Blood', 'donation', 'camp', 'organised'],
#  ['The', 'policemen', 'find', 'new', 'excuse:', 'Television', 'slums'],
#  ['Paramour;', 'accomplice', 'get', 'life', 'term', 'killing', 'woman'],
#  ['Policing', 'metro:', 'Year-end', 'musings'],
#  ['Sangh', 'Parivar;', 'Babri', 'panel', 'ante'],
#  ['Frontrunner', 'key', 'US', 'post', 'seen', 'Pak', 'tilt'],
#  ['Muslims', 'see', 'red', 'Coke', 'logo'],
#  ['Move', 'Nepal;', 'Casino', 'Goa'],
#  ['Merit', 'Calling'],
#  ['Closures', 'putting', 'financial', 'strain', 'Delhi', 'Govt'],
#  ['42', 'units', 'sealed', 'phase-II', 'operation', 'closure'],
#  ['Special', 'trains', 'Kumbh', 'Mela'],
#  ['CPM', 'survey', 'units'],
#  ['NIEPA', 'meet', 'discuss', 'issue', 're-employing', 'retired', 'teachers'],
#  ['Such', 'long', 'journey', 'green', 'dispenser'],
#  ['Woman', 'fighting', 'life', "'quack'", 'performed', 'MTP'],
#  ['Cold', 'weather', 'puts', 'strain', 'people', 'weak', 'hearts'],
#  ['Secrecy', 'place', 'democracy;', 'says', 'Sorabjee'],
#  ['On', 'hitlist', 'polluting', 'units'],
#  ['Driver', 'makes', 'cash', "employer's", 'Zen'],
#  ['Rs', '25;000', 'compensation', '10-yr-old', 'domestic', 'help'],
#  ['What', 'one', 'backache', "'epidemic'"],
#  ['Criminals', 'beat', 'family', 'iron', 'rods'],
#  ['Three', 'held', 'stealing', 'power'],
#  ['Road', 'accident', 'toll', 'Noida', '130', 'last', 'year'],
#  ['Blood', 'donation', 'camp', 'organised'],
#  ['The', 'policemen', 'find', 'new', 'excuse:', 'Television', 'slums'],
#  ['Paramour;', 'accomplice', 'get', 'life', 'term', 'killing', 'woman'],
#  ['Policing', 'metro:', 'Year-end', 'musings'],
#  ['Sullied', 'Symbol'],
#  ['Sullied', 'Symbol'],
#  ['Temple', 'Tactics'],
#  ['Conflict', 'Diamonds'],
#  ["Vajpayee's", 'Musings'],
#  ['Sabarimala;', 'Abode', 'Of', 'Lord', 'Ayyappa'],
#  ['Pleasure', 'Principle'],
#  ['Concept', 'Creation'],
#  ["I'm", 'supporter', 'LTTE:', 'Nedumaran'],
#  ['HAL', 'showcase', 'pride', 'Aero-2001'],
#  ['I', 'prove', 'charges', 'Mishra:', 'J', 'K', 'Jain'],
#  ['Samata', 'faces', 'split', 'JD', 'merger'],
#  ['Cellphone', 'proving', 'curse', 'mafia'],
#  ['The', 'Kamasutra', 'girl', 'real', 'cool'],
#  ['Ayurveda', 'oil', 'massage'],
#  ['Balle', 'Balle', 'Boys', 'hit', 'charts'],
#  ['Financier',
#   'Bharat',
#   'Shah',
#   'held',
#   'alleged',
#   'links',
#   'Chotta',
#   'Shakeel'],
#  ['Officials', 'brace', "millennium's", 'first', 'Mahakumbh'],
#  ['Material', 'souls', 'seek', 'salvation', 'Ganga'],
#  ['Vajpayee', 'woos', 'Vietnam', 'infotech'],
#  ['All', 'party', 'meet', 'joint', 'cadre', 'issue', 'soon:', 'CM'],
#  ['One', 'advocate', 'general', 'Goa', 'soon'],
#  ['Order', 'plastic', 'ban', 'soon'],
#  ['Campaign', 'educate', 'vendors', 'selling', 'cigarette;', 'gutka'],
#  ['Hike', 'water', 'tariff', 'March'],
#  ['Construction', 'Swatantra', 'Veer', 'Chowk', 'mooted'],
#  ['Lunar', 'eclipse', 'Jan.', '9', '10'],
#  ['Hefty', 'phone', 'bill', 'shocks', 'officials'],
#  ['50', 'handicaps', 'get', 'artificial', 'limbs'],
#  ['ABVP', 'organises', 'reception', 'students'],
#  ['Infrastructure', 'development', 'corporation', 'constituted'],
#  ['Seminar', 'industrial', 'gases', 'Jan.', '19'],
#  ['New', 'molecule', 'fight', 'malaria', 'found'],
#  ["Brain's", 'sensory', 'filter', 'smaller', 'schizophrenics'],
#  ['Mice', 'blame', 'childhood', 'asthma?'],
#  ['Controlled', 'drinking', 'may', 'answer', 'alcoholics'],
#  ['No', 'radiation', 'sickness', 'among', 'Bulgarian', 'troops'],
#  ['STF', 'working', 'without', 'sleep;', 'food:', 'Sangliana'],
#  ['Danger', 'lurks', 'city', 'pubs'],
#  ["Centre's", 'ditherings', 'dangerous:', 'Chandra', 'Shekhar'],
#  ['New', 'tariffs', 'bad', 'news', 'cellphone', 'operators'],
#  ['Jaya', 'Jaitly', 'unanimously', 'elected', 'Samata', 'chief'],
#  ['Bus', 'station', 'Shivajinagar', 'set', 'open'],
#  ['CM', 'gets', "'majority", "darshan'"],
#  ['CET', 'Cell', 'returns', 'Rs', '13', 'cr', 'govt'],
#  ['Ranebennur', 'tense;', 'bandh', 'successful'],
#  ['Britisher', 'found', 'dead'],
#  ['Take', 'citizens', 'confidence;', 'CM', 'tells', 'police'],
#  ['State', 'crack', 'illegal', 'plastic', 'production'],
#  ['Krishna', 'reviews', 'matters', 'constituency'],
#  ['Now', 'JD(S)', 'gives', 'clearance', 'merger', 'JD(U)'],
#  ['Shoulder', 'injury', 'sends', 'Kumble', 'spin'],
#  ['Treasury', 'dept', 'computerised', 'year'],
#  ['Art', 'exhibition', 'raise', 'funds', 'music', 'school'],
#  ['Cotton', 'row:', 'Govt', 'open', 'talks'],
#  ['TADA', 'judge', 'issues', 'notices', '10', 'witnesses'],
#  ['Grid', 'problems', 'hits', 'power', 'supply'],
#  ['Probe', 'ordered', 'chick', 'colouring'],
#  ['Has', 'it;', 'flaunt'],
#  ['Falun', 'Gong', 'free', "can't", 'sell', 'spiritualism'],
#  ['Erosion', 'value', 'system', 'civil', 'society'],
#  ['Contempt', 'notice', 'disobeying', 'HC', 'order'],
#  ['Medical', 'evidences', 'corroborate', 'charges', 'levelled', 'victim'],
#  ['BCC', 'submits', 'memo', 'HC'],
#  ['The', 'best', 'things', 'life'],
#  ['Superstition;', 'poverty', 'increasing', 'AIDS', 'cases'],
#  ['Financier',
#   'Bharat',
#   'Shah',
#   'held',
#   'alleged',
#   'links',
#   'Chotta',
#   'Shakeel'],
#  ['Officials', 'brace', "millennium's", 'first', 'Mahakumbh'],
#  ['Material', 'souls', 'seek', 'salvation', 'Ganga'],
#  ['Vajpayee', 'woos', 'Vietnam', 'infotech'],
#  ['All', 'party', 'meet', 'joint', 'cadre', 'issue', 'soon:', 'CM'],
#  ['One', 'advocate', 'general', 'Goa', 'soon'],
#  ['Order', 'plastic', 'ban', 'soon'],
#  ['Campaign', 'educate', 'vendors', 'selling', 'cigarette;', 'gutka'],
#  ['Hike', 'water', 'tariff', 'March'],
#  ['Construction', 'Swatantra', 'Veer', 'Chowk', 'mooted'],
#  ['Lunar', 'eclipse', 'Jan.', '9', '10'],
#  ['Hefty', 'phone', 'bill', 'shocks', 'officials'],
#  ['50', 'handicaps', 'get', 'artificial', 'limbs'],
#  ['ABVP', 'organises', 'reception', 'students'],
#  ['Infrastructure', 'development', 'corporation', 'constituted'],
#  ['Seminar', 'industrial', 'gases', 'Jan.', '19'],
#  ['New', 'molecule', 'fight', 'malaria', 'found'],
#  ["Brain's", 'sensory', 'filter', 'smaller', 'schizophrenics'],
#  ['Mice', 'blame', 'childhood', 'asthma?'],
#  ['Controlled', 'drinking', 'may', 'answer', 'alcoholics'],
#  ['No', 'radiation', 'sickness', 'among', 'Bulgarian', 'troops'],
#  ['STF', 'working', 'without', 'sleep;', 'food:', 'Sangliana'],
#  ['Danger', 'lurks', 'city', 'pubs'],
#  ["Centre's", 'ditherings', 'dangerous:', 'Chandra', 'Shekhar'],
#  ['New', 'tariffs', 'bad', 'news', 'cellphone', 'operators'],
#  ['Jaya', 'Jaitly', 'unanimously', 'elected', 'Samata', 'chief'],
#  ['Bus', 'station', 'Shivajinagar', 'set', 'open'],
#  ['CM', 'gets', "'majority", "darshan'"],
#  ['CET', 'Cell', 'returns', 'Rs', '13', 'cr', 'govt'],
#  ['Ranebennur', 'tense;', 'bandh', 'successful'],
#  ['Britisher', 'found', 'dead'],
#  ['Take', 'citizens', 'confidence;', 'CM', 'tells', 'police'],
#  ['State', 'crack', 'illegal', 'plastic', 'production'],
#  ['Krishna', 'reviews', 'matters', 'constituency'],
#  ['Now', 'JD(S)', 'gives', 'clearance', 'merger', 'JD(U)'],
#  ['Shoulder', 'injury', 'sends', 'Kumble', 'spin'],
#  ['Treasury', 'dept', 'computerised', 'year'],
#  ['Art', 'exhibition', 'raise', 'funds', 'music', 'school'],
#  ['Cotton', 'row:', 'Govt', 'open', 'talks'],
#  ['TADA', 'judge', 'issues', 'notices', '10', 'witnesses'],
#  ['Officials', 'brace', "millennium's", 'first', 'Mahakumbh'],
#  ['Fend', 'yourselves;', 'Pande', 'tells', 'doctors'],
#  ['Bureaucracy', 'undermining', "legislature's", "'existence'"],
#  ['State', 'police', 'collapses', 'pressure'],
#  ['Court', 'declares', 'Pappu', 'Yadav', 'absconder'],
#  ['shreyas', 'gopal', 'scores', 'ton', 'karnataka', 'stay', 'top', 'mumbai'],
#  ['japan', 'edge', 'north', 'korea', 'politically', 'charged', 'opener'],
#  ['Sonia', 'takes', 'Hindutva', 'brigade'],
#  ['Congress', 'hopes', 'soar;', 'BJP', 'cries', 'foul'],
#  ['Ceasefire', 'decision', 'likely', 'today'],
#  ['Ceasefire', 'blues:', 'To', 'end', 'extend', 'truce'],
#  ['So', 'Young;', 'So', 'Successful'],
#  ['Kumbh', 'Karma'],
#  ['Greenmail', '&', 'White', 'Knights'],
#  ['Child', 'Fortune'],
#  ['One-way', 'Street'],
#  ['Towards', 'Theory', 'Everything', '-', 'II'],
#  ['Seeing', 'Believing'],
#  ['Meditation'],
#  ['Wockhardt', 'plans', 'another', 'cardiac', 'centre'],
#  ['Inside', 'Track'],
#  ['CM',
#   'action',
#   'officials',
#   'depositing',
#   'funds',
#   'non-scheduled',
#   'banks'],
#  ['Blood', 'donation', 'safe', 'hospitals'],
#  ['BJP', 'asks', 'govt', 'learn', 'lessons', "'failed", "MoUs'"],
#  ['Surveillance', 'along', 'coastal', 'belt', 'stepped'],
#  ['Cong', 'opposes', 'Vaze', 'GPSC', 'chief'],
#  ['Minister', 'verify', 'info', 'Goans', 'star', 'hotels'],
#  ['Tillari:', 'Rehabilitation', 'first;', 'says', 'Oppn'],
#  ['Rape', 'accused', 'acquitted'],
#  ['Milk', 'price', 'hike:', 'Govt', 'rethink'],
#  ['Career', 'information', 'fair', 'Feb', '17'],
#  ['Assembly', 'congratulates', 'Anil', 'Kakodkar'],
#  ['Multi-religious', 'meet', 'held'],
#  ['Kirti', 'Reddy', "'Pyaar", 'Ishq', 'Aur', "Mohabbat'!"],
#  ['Nasir', 'Khan:', 'Small', 'big!'],
#  ['Pooja', 'Batra:', 'Curry', 'Pooja!'],
#  ['Shamita', 'Shetty:', "'Mohabbat'", 'way'],
#  ['Pankaj', 'Udhas:', 'Technological', 'voices!'],
#  ['Kirti', 'Reddy', "'Pyaar", 'Ishq', 'Aur', "Mohabbat'!"],
#  ['Pankaj', 'Udhas:', 'Technological', 'voices!'],
#  ['Pooja', 'Batra:', 'Curry', 'Pooja!'],
#  ['Shamita', 'Shetty:', "'Mohabbat'", 'way'],
#  ['Nasir', 'Khan:', 'Small', 'big!'],
#  ['Bajaj', 'Auto', 'sell', '26%', 'tempo', 'arm;', 'withdraw', 'name'],
#  ['Timex', 'create', 'new', 'image', '180', 'models'],
#  ['Kawasaki', 're-negotiate', 'stake', 'purchase'],
#  ['NIIT', 'net', 'seen', '50', 'per', 'cent', 'Rs', '27', 'crore'],
#  ['Now;', 'imported', 'products', 'need', 'meet', 'Indian', 'standard'],
#  ['Branded', 'jewellery', 'set', 'dazzle'],
#  ['Net', 'familiarity', 'drive', 'e-commerce'],
#  ['Net', 'familiarity', 'drive', 'e-commerce'],
#  ['Digitalising', 'consultancy', 'Orbit-e'],
#  ['Way2Wealth', 'positions', 'one-stop', 'financial', 'shop'],
#  ['Govt', 'table', '13', 'bills', 'ongoing', 'assembly', 'session'],
#  ['Cong', 'leaders', 'asked', 'decide', 'tie', 'Trinamul'],
#  ['CPM', 'interference', 'agriculture', 'varsity'],
#  ['Nation-wide', 'red', 'alert', 'regarding', 'toxic', 'tea'],
#  ['Viren', 'Shah', "'out-walks'", 'Opposition'],
#  ['Highlights', 'Viren', 'J.', "Shah's", 'speech'],
#  ['Sramik', 'Union', 'supports', 'Baranagar', 'mill', 'violence'],
#  ['CMC', 'seeks', 'police', 'help', 'protect', 'statues'],
#  ['Increase', 'Haj', 'pilgrims', 'state'],
#  ["'Withholding", "teachers'", 'salaries', 'collective', "decision'"],
#  ['Ceasefire', 'camouflages', 'factional', 'strife', 'Nagaland'],
#  ['NHRC', 'issues', 'notice', 'WB', 'home', 'secy'],
#  ['Protest', 'port', 'Kulpi'],
#  ['Mamata', 'attend', 'police', 'body', 'meet', 'today'],
#  ["'Empowered'", 'women', 'Kochpukur', 'impress', 'Lara'],
#  ['Medical', 'college', 'Sikkim', 'July'],
#  ['Govt', 'extends', 'J&K', 'ceasefire', 'month'],
#  ['Peace', 'hinges', 'human', 'rights'],
#  ['Two', 'crore', 'Mahakumbh', 'big', 'bath'],
#  ['Minister', 'inquired', 'Hinduja', 'passport;', 'admits', 'UK'],
#  ['First', 'R&D;', 'food'],
#  ['Globo', 'God'],
#  ["Pilgrim's", 'Process'],
#  ['Sustainable', 'Ceasefire'],
#  ['Beauty', 'Beast'],
#  ['Urban', 'Apartheid'],
#  ['Spiritual', 'Quotient', 'Leverages', 'IQ', '&', 'EQ'],
#  ['The', 'Veggie', 'Abroad'],
#  ['Purifying', 'Ourselves'],
#  ['Labour', 'Law'],
#  ["Boby's", 'fight', 'love'],
#  ['Dharmendra:', 'Suicide', 'Suicide!'],
#  ['Sunny', 'Deol:', 'Lessons', 'Learned!'],
#  ['British', 'Indian', 'present', 'Kama', 'Sutra', 'series'],
#  ['Farouq', 'Rattonsey:', 'Third', 'Time', 'Lucky?'],
#  ['Welfare', 'fund', 'film', 'artistes'],
#  ['Our', 'department', 'life'],
#  ['Bitter', 'reality', 'bared'],
#  ['Keep', 'danbruff', 'arms', 'distance'],
#  ['Awareness', 'essential'],
#  ['A', 'Fashion', 'excuse'],
#  ['Plane', 'mishap', 'averted', 'Patna'],
#  ['Two', 'CPI(ML)', 'activists', 'die', 'Gaya', 'police', 'firing'],
#  ['Gold', 'gifts', 'Misa', 'may', 'trouble', 'presenters'],
#  ['Police', 'hesitant', 'lodging', 'case', 'Sadhu;', 'Modi'],
#  ['CPI', 'decides', 'continue', 'agitation'],
#  ['Jharkhand', 'govt', 'set', 'power', 'grid'],
#  ['Minister', 'warns', 'banks', 'economic', 'non-cooperation'],
#  ['Dalit', 'outfits', 'hold', 'rally', 'HC'],
#  ['Court', 'asks', 'DG', 'travel', 'highways', 'Bihar'],
#  ['3', 'cellphones', 'recovered', 'Muzaffarpur', 'jail'],
#  ['Trader', 'freed', 'payment', 'Rs', '2.5', 'crore'],
#  ["Samata's", 'Kurmi', 'card', 'test', 'Asthawa'],
#  ['Govt', 'seek', 'fresh', 'cadre', 'option', 'staff'],
#  ['LNMU', 'V-C', 'cancels', "teachers'", 'deputation', 'town', 'colleges'],
#  ['Shamiana', 'replaces', 'exam', 'halls'],
#  ['Cellphone', 'services', 'loggerheads', 'Patna'],
#  ['Concentrate', 'developmental', 'activities:', 'Naidu'],
#  ['TDP', 'rock', 'NDA', 'boat:', 'Naidu'],
#  ['Noose', 'tightens', 'causing', 'noise', 'pollution'],
#  ['Centre', 'give', 'big', 'push', 'herbal', 'sector'],
#  ['Big', 'bath', 'passes', 'without', 'hitch'],
#  ['Security', 'bandobast:', 'The', 'one', 'got', 'away'],
#  ['Enron', 'allowed', 'enhance', 'stake', 'Dhabol', 'project'],
#  ['Govt', 'discretionary', 'powers', 'deny', 'passports'],
#  ['A', 'view', 'far', 'near'],
#  ["'Temptation", "Island'", 'beats', "'The", "Mole'"],
#  ['Kasparov', 'drubs', 'Shirov;', 'takes', 'joint', 'lead'],
#  ['Dino', 'Morrea:', 'Bhatt;', 'seriously!'],
#  ['Kabhi', 'Insured', 'Kabhi', 'Nahi!'],
#  ["'Samosa", "Queen'", 'among', 'richest', 'UK', 'businesswomen'],
#  ['Ustad', 'Zakir', 'Hussain:', 'Drumming', 'high'],
#  ['Priyadarshan:', 'Angrezi', 'Babu?'],
#  ['Dino', 'Morrea:', 'Bhatt;', 'seriously!'],
#  ['Ministers', 'threat'],
#  ['A', 'wait', 'vain', 'young', 'neighbours?'],
#  ['No', 'tableaux', 'yet', 'brand-new', 'states'],
#  ['Birds', 'pecking', 'meatshop', 'waste', 'may', 'disrupt', 'flypast'],
#  ['DDA', 'take', 'responsibility', 'power;', 'water', 'properties:', 'Court'],
#  ['How', 'much', 'longer;', 'SC', 'asks', 'govt'],
#  ['The', 'court', 'faith', 'us:', 'Jagmohan'],
#  ['MCD', 'begins', 'clean-up', 'act'],
#  ['Illegal', 'arms', 'flood', 'Delhi'],
#  ['Killer', 'roads', 'claim', 'more;', '7', 'dead', '24', 'hrs'],
#  ['Link', 'Noida-South', 'Delhi', 'slashes', 'distances'],
#  ['Tax', 'doubles', 'Noida', 'schoolbus', 'fee;', 'parents', 'upset'],
#  ['Dancing',
#   'pleasure;',
#   'give',
#   'us',
#   'hot',
#   'food',
#   'water;',
#   'say',
#   'artistes'],
#  ['IPI', 'world', 'congress', 'comes', 'back', 'India'],
#  ['No', 'monkey', 'business', 'this:', 'A', 'sarkari', 'simian', 'safari'],
#  ["Cough's", 'good;', 'could', 'damage', 'heart'],
#  ['Keep', 'dress', 'code', 'light-coloured'],
#  ['Man', 'gets', 'life', 'term', 'burning', 'mother', 'death'],
#  ['Of', 'long', 'hours', 'short', 'fuses...'],
#  ['Steve', 'Waugh', 'yet', 'speak', 'brother', 'matchfixing'],
#  ['Aussies',
#   'play',
#   'Mumbai',
#   'Brabourne;',
#   'Cammie',
#   'Smith',
#   'match',
#   'referee'],
#  ["Kumble's", 'absence', 'may', 'encourage', 'youngsters:', 'Dravid'],
#  ['Chris', 'Cairns', 'undergo', 'surgery'],
#  ['Aussies',
#   'play',
#   'Mumbai',
#   'Brabourne;',
#   'Cammie',
#   'Smith',
#   'match',
#   'referee'],
#  ['Stage', 'set', "France's", 'first', 'final', '63', 'years'],
#  ['Stage', 'set', "France's", 'first', 'final', '63', 'years'],
#  ['Agassi', 'prepares', 'face', 'Rafter', 'semifinal'],
#  ['Gift', 'bride'],
#  ['Will', 'Chinese', 'kill', 'us', '?'],
#  ['The', 'sound', 'Alabina'],
#  ['Municipal', 'staff', 'storm', "Commissioner's", 'office'],
#  ['Cong', 'come', "'black", "papers'"],
#  ['Strategy', 'papers', 'far', 'fetched:', 'Cong;', 'CPI'],
#  ['Organised', 'Crime', 'Act', 'good', 'TADA'],
#  ['Austech', 'plans', 'mini', 'IT', 'university', 'Punjab'],
#  ['Police', 'bust', '3', 'member', 'gang', 'burglars'],
#  ['Surjewala', 'blames', 'govt', 'inflation'],
#  ['Congress', 'hopeful', 'winning', 'Majitha', 'seat'],
#  ['SGPC', 'appoints', 'new', 'charge', 'sub', 'office'],
#  ['Displaced',
#   'Slum-dwellers',
#   'force',
#   'HUDA',
#   'allot',
#   'alternative',
#   'site'],
#  ['Haryana', 'sell', 'surplus', 'land;', 'buildings', 'capital', 'fund'],
#  ['No', 'breakthrough', 'Panchkula', 'double', 'murder'],
#  ['Chautala', 'lays', 'stone', 'Sinchai', 'Bhawan'],
#  ['Congress', 'seeks', 'upset', 'SAD', 'applecart', 'Majitha', 'by-poll'],
#  ['Suspected', 'infiltration;', 'PU', 'hostel', 'raided'],
#  ['A', 'night', 'terror', 'Saketri'],
#  ['UBS', 'faculty', 'wants', 'financial', 'autonomy'],
#  ['AIDS', 'assuming', 'epidemic', 'proportions'],
#  ['New', 'life', 'styles;', 'food', 'habits', 'blame', 'heart', 'disease'],
#  ['Complaint', 'hospital', 'dismissed'],
#  ['Ashadeep', 'lends', 'IGMC', 'helping', 'hand'],
#  ['Haryana', 'gets', 'ready', "PM's", 'visit'],
#  ['CBSE', 'evinces', 'interest', 'UT', 'weekly', 'tests', 'programme'],
#  ['The', 'life-style', 'disease', 'leads', 'blindness'],
#  ["'Wireless",
#   'data',
#   'networks',
#   'necessary',
#   'reliable',
#   'connectivity',
#   'inaccessible',
#   'areas'],
#  ['Road', 'Rly', 'station', 'highway', 'closed', 'city', 'traffic'],
#  ['Rice', 'miller', 'nabbed'],
#  ['New', "Article'Inside", 'outside;', 'two-wheeler', "unsafe'"],
#  ['Zero', 'Slum', 'Game'],
#  ['Exit', 'Estrada'],
#  ['Kabhi', 'Cushy;', 'Kabhi', 'Grim'],
#  ['President', 'pitch', 'indirect', 'polls'],
#  ['TRAI', 'orders', 'refund', 'crores', 'cellphone', 'users'],
#  ['Soccer', 'helps', 'heal', 'wounds', 'war'],
#  ['Settlur', 'grilled', 'affair', 'Becker'],
#  ["'KBC':", 'nothing', 'compares', 'you!'],
#  ['Raveena', 'Tandon', "Noorani's", "'Dreamcatcher'"],
#  ['Sunny', 'Deol:', "'dillagi'", 'towards', "'Indian'!"],
#  ['Recipe', 'Anil', "Kapoor's", 'cook', 'book!'],
#  ['Yash', 'Pathak:', 'Wonder', 'boy!'],
#  ['Chandrasekhar', 'comedy;', 'Sundance', 'festival', 'hit'],
#  ['Kiran', 'Bedi', 'dons', 'new', 'role', 'promote', 'love'],
#  ['Inquiry', 'net', 'Hinduja', 'citizenship', 'widens'],
#  ["Mendonca's", 'powers', 'curtailed'],
#  ['SP;', 'JD', '(S)', 'Muslim', 'members', 'set', 'join', 'NCP'],
#  ['Navi', 'Mumbai', 'witnessed', 'fall', 'crime', '2000'],
#  ['Miss', 'India', 'pageant', 'showcases', 'mermaids', 'wonderworld'],
#  ["Mumbai's", 'youth', 'gung-ho', 'India'],
#  ['New', 'car', 'pool', 'portal', 'solve', 'traffic', 'chaos'],
#  ['Competition', 'spurs', 'LIC', 'market-linked', 'policy'],
#  ['HC', 'wants', 'rules', 'framed', 'appointment', 'trustees'],
#  ['AI', 'undecided', 'installing', 'new', 'TV', 'sets'],
#  ["Hawking's", 'disabilities', 'focus', 'publicity'],
#  ['Sahitya', 'sammelans', 'conveyed', 'opposite', 'ideologies'],
#  ['UN', 'report', 'warns', 'global', 'warming'],
#  ['Tea', 'protect', 'heart', 'ailments;', 'diabetes'],
#  ['Indian', 'fashion', 'continue'],
#  ['Is', 'Movie', 'Tower', 'haunted?'],
#  ['Imprisonment', 'taking', 'toll', 'Speight'],
#  ['Bush', 'inaugural', 'evokes', 'strong', 'feelings', 'among', 'Indians'],
#  ["Physicist's", 'endowment', 'funds', 'Indo-US', 'nuclear', 'talks'],
#  ['Human', 'rights', 'beyond', 'legal', 'framework:', 'Amartya', 'Sen'],
#  ['US', 'citizens', 'Nepal', 'may', 'targeted', 'Maoists'],
#  ['Nepali', 'minister', 'resigns', 'airline', 'lease', 'scam'],
#  ['Indo-Bangla', 'passenger', 'train', 'service', 'soon'],
#  ['Pressure', 'continue', 'Tigers:', 'Wickremanayake'],
#  ['Muslim', 'minister', 'strikes', 'deal', 'Kumaratunga'],
#  ['Monster', 'quake', 'kills', '15;000'],
#  ['Daddy', 'see;', 'balcony', 'shaking...'],
#  ['Forces', 'rescue'],
#  ['Monster', 'quake', 'kills', '4;000'],
#  ['Forces', 'rescue'],
#  ['Centre', 'promises', 'aid'],
#  ['PM', 'appeals', 'help'],
#  ['Daddy', 'see;', 'balcony', 'shaking...'],
#  ['The', 'unpredictable', 'calamity'],
#  ['British', 'promoter', 'Jonathan', 'King', 'faces', 'sex', 'charges'],
#  ['Shah', 'Rukh', 'Khan:', 'Sporting', 'spirit'],
#  ['Rani', 'Mukherjee:', 'Chi', 'chi', 'fancies'],
#  ['Keerthi', 'Reddy:', 'Still', 'jadoo', 'do?'],
#  ["Let's", 'Cell-eberate'],
#  ['A', 'True', 'Republican'],
#  ['Mamata', 'Express'],
#  ['Stoking', 'Sentiment'],
#  ['St', 'Francis;', 'Patron', 'Saint', 'Ecology'],
#  ['The', 'Learning', 'Curve'],
#  ['Songs', 'Freedom'],
#  ['Another', 'Duleep', 'double', 'Mongia'],
#  ['France;', 'India', 'hold', 'strategic', 'talks'],
#  ['Acceptances', 'Delhi', 'races'],
#  ['Canadian', 'airline', 'sponsor', 'Mumbai', 'Marathon', 'Hope'],
#  ['US', 'Congressmen', 'urged', 'join', 'India', 'caucus'],
#  ['Pak', 'brothers', 'arrested', 'US', 'sting', 'operation'],
#  ['Indian;', 'Pakistani', 'delegates', 'clash', 'Disarmament', 'Conference'],
#  ['Indians;', 'Pakistanis', 'con', 'S', 'African', 'women', 'marriages'],
#  ['Millennium', 'Cup', 'promoters', 'wiser', 'lot'],
#  ['Footballers', 'Bangalore', 'proud'],
#  ['Pak', 'welcomes', 'train', 'accord', 'extension', 'India'],
#  ['Insurance', 'firm', 'compensate', 'accident', 'victim'],
#  ['Rallyists;', 'tremor-hit', 'keep', 'cops', 'busy'],
#  ['Police', 'put', 'feet'],
#  ['Of', 'crimes', 'times', 'dotcons'],
#  ['An', 'excise', 'exercise', 'line', 'duty'],
#  ['If', 'caught;', 'stick', 'sturdy'],
#  ['Govt', 'dispensaries', 'open', 'night'],
#  ['Panel', 'flays', "DDA's", 'Manhattan', 'mania', 'Yamuna'],
#  ['Rural', 'sector', 'get', 'top', 'priority:', 'L-G'],
#  ['History', 'datelist', 'help', 'census'],
#  ['HC', 'asks', 'Centre', 'ATR', 'naval', 'missile', 'battery', 'case'],
#  ['Builders', 'spend', 'safety:', 'Experts'],
#  ['This', 'end;', 'predict', 'astrologers'],
#  ['Is', 'clock', 'ticking', 'Delhi?'],
#  ['Party', 'potboiler:', 'Man;', 'cook!'],
#  ['Tremors', 'fail', 'jolt', 'Govts', 'action:', 'PIL'],
#  ['Relative', 'kills', '9-year-old'],
#  ['Bovine', 'Biotech:', 'Milking', 'microbes', 'dry'],
#  ['The', 'unpredictable', 'calamity'],
#  ['Centre', 'promises', 'aid'],
#  ['Death;', 'distress;', 'destruction...and', 'yet'],
#  ['The', 'town', 'Bhuj'],
#  ['Massive', 'rescue', 'save', 'Gujarat'],
#  ['300', 'children', 'trapped'],
#  ['Jnanpith', 'awarded', 'Nirmal', 'Verma;', 'Gurdial', 'Singh'],
#  ['Lata', 'overwhelmed', 'Bharat', 'Ratna'],
#  ['Guess', "Neha's", "'Ehsaas'"],
#  ['Mahesh', 'Manjrekar:', 'Primary', 'colours'],
#  ['Damle', 'acts', 'non-stop', '15', 'hours'],
#  ['DoCoMo', 'eyeing', 'US', 'market'],
#  ['NexTone', 'partner', 'Cognitronics'],
#  ['Quake', 'affects', 'telecom;', 'power'],
#  ['Autolite', 'India', 'exonerated', 'French', 'court'],
#  ['Titan', 'Q3', 'sales', '8.3', 'per', 'cent'],
#  ['India', 'woos', 'US', 'oil', 'industry'],
#  ['JCPK', 'money'],
#  ['Nature', 'cruellest', 'killer'],
#  ['Quakeffect:', 'Investors', 'need', 'worry'],
#  ["It's", 'online:', 'Travel', 'roll'],
#  ['Over', '150', 'exporters', 'participate', 'garment', 'fair'],
#  ['NexTone', 'partner', 'Cognitronics'],
#  ['DoCoMo', 'eyeing', 'US', 'market'],
#  ['The', 'Word', 'Factory'],
#  ['She', 'could', 'danced', 'night'],
#  ['We', 'unable', 'face', 'reality'],
#  ['The', 'Kiteman', 'cometh'],
#  ['Hyphenating', 'cinema'],
#  ['At', 'home', 'Minister'],
#  ['He', 'sexiest', 'man', 'India'],
#  ['Of', 'fortune', '&', 'Feng', 'Shui'],
#  ['Can', 'RSS', 'man', 'become', 'ISI', 'agent'],
#  ['She', 'levitates', 'social', 'ladder'],
#  ['Is', 'Republic', 'Day', 'parade', 'step', 'times?'],
#  ['Our', 'Secular', 'Brew'],
#  ['Unholy', 'Smokes'],
#  ["Don't", 'rob', "Prashant's", 'future'],
#  ['Shilanayas', 'allowed', 'avoid', 'bloodbath'],
#  ['Constable', 'arrested', 'shooting', 'AIIMS', 'employee'],
#  ['Another', 'example', 'police', 'high-handedness'],
#  ['How', 'sound', 'ground', 'beneath', "Delhi's", 'feet?'],
#  ['Can', 'Delhi', 'deal', 'disasters?'],
#  ['Hospitals', 'far', 'equipped'],
#  ['Ill-prepared', 'disaster'],
#  ['28-yr-old', 'found', 'dead', 'bathroom'],
#  ['Cops', 'gearing', 'face', 'new', 'threats'],
#  ["Don't", 'Rob', "Prashant's", 'Future'],
#  ['More', 'tremors', 'forecast', 'next', '48', 'hours'],
#  ['The', 'town', 'lay', 'forgotten', '36', 'hours'],
#  ['Gujarat', 'finds', 'hope', 'army', 'good', 'Samaritans'],
#  ['Too', 'much;', 'late'],
#  ['Govt', 'opens', 'purse-strings;', 'seeks', '$1.5', 'bn', 'loan'],
#  ['Hrithik', 'Roshan:', 'Organised', 'chaos'],
#  ['Twinkle', 'Khanna:', 'Dramabaazi!', 'This', 'time', 'stage!'],
#  ['Mahesh;', 'Satnam:', 'Best', 'buddies'],
#  ['Wide', 'acclaim', 'Indian', 'films', 'US', 'festival'],
#  ["'Kuch", 'Kuch', 'Hota', "Hai'", 'craze', 'SE', 'Asia'],
#  ['Hrithik', 'Roshan:', 'Organised', 'chaos'],
#  ['Hey', 'Ram;', 'Karunam;', 'Hum', 'Dil...', 'big', 'draw', 'US', 'fest'],
#  ['Gun', 'Culture'],
#  ['BJP', 'whisks', 'Cong', 'MLA', 'plans'],
#  ['Assistant', 'bank', 'manager', 'held', 'arms', 'scandal'],
#  ['59-year-old', 'widow', 'murdered'],
#  ['Fiji', 'Hindus', 'protest', 'religious', 'curbs'],
#  ['Australia', 'pledges', '$1', 'quake', 'victims'],
#  ['Taiwan', 'activists', 'plan', 'sit-in', 'nuclear', 'project'],
#  ['Angolan', 'president', 'arrives', 'Japan'],
#  ['After', 'Shock'],
#  ['Honours', 'Even'],
#  ['Step', 'Step'],
#  ['Processing', 'Peace'],
#  ['Basant', ':', 'Festival', 'Renewal', 'Hope'],
#  ['Night', 'Bus', 'Ajmer'],
#  ['Maha', 'Saraswati'],
#  ['The', 'Enchanted', 'Forester'],
#  ['The', 'question', 'started', 'Hinduja', 'affair'],
#  ['Tigers', 'refuse', 'sign', 'Norwegian', 'peace', 'deal'],
#  ['Kuwait', 'Red', 'Cross', 'donates', '$250;000', 'quake', 'victims'],
#  ['UAE', 'NRIs', 'mobilise', 'relief', 'quake', 'victims'],
#  ['Tigers', 'refuse', 'sign', 'Norwegian', 'peace', 'deal'],
#  ['Fiji', 'Hindus', 'protest', 'religious', 'curbs'],
#  ['Students', 'back', 'home', 'safe', 'trauma', 'Gujarat'],
#  ['No', 'aftershock', 'here:', 'Bangalorean', 'safe'],
#  ['State', 'sends', 'para-medical', 'staff', 'quake-hit', 'areas'],
#  ...]

# %%
cv=CountVectorizer()
word_count_vector=cv.fit_transform(headlines['new_headlines'])

# %%
#this is word document co-occurence matrix
word_count_vector,word_count_vector.shape
# Out:
# (<100000x36612 sparse matrix of type '<class 'numpy.int64'>'
#  	with 475117 stored elements in Compressed Sparse Row format>,
#  (100000, 36612))

# %%
tfidf=TfidfTransformer(smooth_idf=False)
tf_idf_vector=tfidf.fit_transform(word_count_vector)

# %%
num_topics=20
model=NMF(n_components=num_topics,init='nndsvd')
model.fit(normalize(tf_idf_vector,norm='l1',axis=1))
# Out:
# NMF(init='nndsvd', n_components=20)

# %%
len(cv.get_feature_names())
# Out:
# 36612

# %%
def top_words_topic(model,n_top_words):
    features=cv.get_feature_names()
    word_dict={}
    for i in range(num_topics):
        word_idx=model.components_[i].argsort()[:-n_top_words-1:-1]
        words=[features[key] for key in word_idx]
        word_dict['topic '+str(i)]=words
    return pd.DataFrame(word_dict)

# %%
words=top_words_topic(model,20)
words
# Out:
#     topic 0     topic 1    topic 2    topic 3    topic 4   topic 5   topic 6  \
# 0      city         the       govt     killed      india       bjp    police
# 1     round  counsellor      staff  militants        pak        up     delhi
# 2    sports        week      state        two      china     polls   station
# 3      scan        mall        may       road  terrorism  congress   custody
# 4    briefs         art        set    kashmir      talks      poll    firing
# 5        up        good         rs  encounter  musharraf        sp     chief
# 6       old         man    schools        one   pakistan        pm  officers
# 7    lights         way        act     mishap        air   gujarat   traffic
# 8       jan       sound       oppn       four      world      modi     alert
# 9     march        word       says    injured       ties    leader    arrest
# 10      feb       story        tax      among    england      sena    attack
# 11    water        king  employees      three      visit       bsp     probe
# 12    areas        that      talks      blast     russia    allies       get
# 13  traffic       music       take     ultras       says     issue      fire
# 14    visit       right      plans   accident        inc     sonia  remanded
# 15    april         was      bihar       hurt      fight    terror      high
# 16    roads       world        law  accidents       miss   ayodhya  security
# 17   centre        best         hc   violence     terror       tdp     crime
# 18    today    speaking       asks     firing       help   leaders    punjab
# 19     hits        path      issue    mishaps        win       vhp  stations
#
#       topic 7 topic 8    topic 9  topic 10   topic 11       topic 12  \
# 0          it     new      power        no       held      statescan
# 1        time    year     supply      says        man         busted
# 2         get   chief     tariff      time        two        seminar
# 3        says    soon       hike  minister     murder           gang
# 4        back    look       cuts    please         rs             tv
# 5   bangalore  policy        cut       yet       fake        listing
# 6      family    york     people    change      three         voters
# 7        khan     set      water     water        one      navaratri
# 8    industry     old  situation        up     seized   brahmotsavam
# 9        love     get    reforms    takers      women         health
# 10     indian    gets    farmers      need  extortion  privatisation
# 11  education   block      theft  decision      woman        centres
# 12   students   takes      woman   kidding     racket      programme
# 13       mind  system      areas    secret    killing     introduced
# 14        big     law       star      biwi       gang          chief
# 15   official     age        hit     trust   workshop    retribution
# 16        hot    high       play       one     busted           dead
# 17     kerala  launch       more      play       wife             rs
# 18        com   plans     crisis      hero     leader           unit
# 19       good  scheme       stir       let       simi           shot
#
#         topic 13   topic 14   topic 15   topic 16   topic 17  topic 18  \
# 0            day       meet       life         us         cm      case
# 1       security      today        get        pak      state        hc
# 2            one         pm       ends     indian     centre    murder
# 3     celebrated        all      woman        may       says      plea
# 4   celebrations     begins       term         pm      water      bail
# 5          today      party       love       says         rs     court
# 6         strike      women  sentenced        war    gujarat   accused
# 7      valentine      water        man       help      seeks        sc
# 8       teachers   tomorrow      bandh       indo      delhi     probe
# 9          world   national     normal  terrorism   minister  arrested
# 10      observed  musharraf       make       ties       work       cbi
# 11       another      opens     strike     attack      visit     order
# 12      hawkings    discuss      death      visit         cr  minister
# 13         field      panel       debt    attacks   congress      gets
# 14      children   students       hits  musharraf       plan    notice
# 15        parade    cauvery        way     terror   governor   hearing
# 16        enters   vajpayee     murder   security  officials      jaya
# 17    celebrates      peace       gets    kashmir       take    centre
# 18        beefed      visit       back    support      meets   phoolan
# 19      republic      calls       real   pakistan    project     death
#
#     topic 19
# 0       cong
# 1      polls
# 2       poll
# 3     leader
# 4    demands
# 5    leaders
# 6        may
# 7      chief
# 8        mla
# 9       back
# 10       ncp
# 11        up
# 12      modi
# 13      says
# 14     rally
# 15      list
# 16  minister
# 17       cpm
# 18        sp
# 19       tdp

# %%
uk=np.array(headlines["headline_category"])
unq_head=np.unique(uk)
unq_head
# Out:
# array(['afghan-children', 'ahmedabad-times', 'analysis',
#        'anti-terror-law', 'astrology.horoscope', 'ayodhya-imbroglio',
#        'bangalore-times', 'blogs', 'bombay-times', 'business',
#        'business.india-business', 'business.international-business',
#        'calcutta-times', 'citizens-grievances', 'city', 'city.ahmedabad',
#        'city.bengaluru', 'city.chandigarh', 'city.chennai', 'city.delhi',
#        'city.hyderabad', 'city.kolkata', 'city.lucknow', 'city.mumbai',
#        'city.patna', 'city.pune', 'city.thiruvananthapuram', 'cricket',
#        'delhi-times', 'edit-page', 'entertainment.english.hollywood',
#        'entertainment.hindi.bollywood', 'food-facts', 'gadgets-news',
#        'home.education', 'home.science', 'home.sunday-times',
#        'home.sunday-times.all-that-matters',
#        'home.sunday-times.deep-focus', 'hyderabad-times',
#        'hyderabad.local-sports', 'india', 'interviews', 'jugular-vein',
#        'life-style.events', 'lucknow-times', 'news', 'only-in-america',
#        'pune-times', 'recipes', 'removed', 'sino-indian-ties',
#        'sports.cricket.india-domestic.ranji-trophy',
#        'sports.cricket.sri-lanka-in-india', 'sports.football',
#        'sports.hockey', 'sports.off-the-field', 'sports.wwe',
#        'swaminomics', 'unknown', 'world.china', 'world.europe',
#        'world.middle-east', 'world.pakistan', 'world.us'], dtype=object)

# %%
unq_head=np.delete(unq_head,np.where(unq_head=="unknown"))
unq_head.shape
# Out:
# (64,)

# %%
cv=CountVectorizer()
head_count_vector=cv.fit_transform(unq_head)
model1=NMF(n_components=num_topics,init='nndsvd')
model1.fit(normalize(tfidf.fit_transform(head_count_vector),norm="l1",axis=1))
# Out:
# NMF(init='nndsvd', n_components=20)

# %%
topics=top_words_topic(model1,1)

# %%
topics
# Out:
#   topic 0   topic 1 topic 2 topic 3 topic 4 topic 5  topic 6  topic 7  \
# 0    city  business   times    news   india   world  cricket  recipes
#
#    topic 8     topic 9 topic 10  topic 11     topic 12 topic 13 topic 14  \
# 0  removed  interviews    blogs  analysis  swaminomics   sports     home
#
#     topic 15 topic 16 topic 17   topic 18 topic 19
# 0  hyderabad    delhi     pune  ahmedabad   afghan

# %%
words.columns=topics.iloc[0,:]

# %%
words
# Out:
# 0      city    business      times       news      india     world   cricket  \
# 0      city         the       govt     killed      india       bjp    police
# 1     round  counsellor      staff  militants        pak        up     delhi
# 2    sports        week      state        two      china     polls   station
# 3      scan        mall        may       road  terrorism  congress   custody
# 4    briefs         art        set    kashmir      talks      poll    firing
# 5        up        good         rs  encounter  musharraf        sp     chief
# 6       old         man    schools        one   pakistan        pm  officers
# 7    lights         way        act     mishap        air   gujarat   traffic
# 8       jan       sound       oppn       four      world      modi     alert
# 9     march        word       says    injured       ties    leader    arrest
# 10      feb       story        tax      among    england      sena    attack
# 11    water        king  employees      three      visit       bsp     probe
# 12    areas        that      talks      blast     russia    allies       get
# 13  traffic       music       take     ultras       says     issue      fire
# 14    visit       right      plans   accident        inc     sonia  remanded
# 15    april         was      bihar       hurt      fight    terror      high
# 16    roads       world        law  accidents       miss   ayodhya  security
# 17   centre        best         hc   violence     terror       tdp     crime
# 18    today    speaking       asks     firing       help   leaders    punjab
# 19     hits        path      issue    mishaps        win       vhp  stations
#
# 0     recipes removed interviews     blogs   analysis    swaminomics  \
# 0          it     new      power        no       held      statescan
# 1        time    year     supply      says        man         busted
# 2         get   chief     tariff      time        two        seminar
# 3        says    soon       hike  minister     murder           gang
# 4        back    look       cuts    please         rs             tv
# 5   bangalore  policy        cut       yet       fake        listing
# 6      family    york     people    change      three         voters
# 7        khan     set      water     water        one      navaratri
# 8    industry     old  situation        up     seized   brahmotsavam
# 9        love     get    reforms    takers      women         health
# 10     indian    gets    farmers      need  extortion  privatisation
# 11  education   block      theft  decision      woman        centres
# 12   students   takes      woman   kidding     racket      programme
# 13       mind  system      areas    secret    killing     introduced
# 14        big     law       star      biwi       gang          chief
# 15   official     age        hit     trust   workshop    retribution
# 16        hot    high       play       one     busted           dead
# 17     kerala  launch       more      play       wife             rs
# 18        com   plans     crisis      hero     leader           unit
# 19       good  scheme       stir       let       simi           shot
#
# 0         sports       home  hyderabad      delhi       pune ahmedabad  \
# 0            day       meet       life         us         cm      case
# 1       security      today        get        pak      state        hc
# 2            one         pm       ends     indian     centre    murder
# 3     celebrated        all      woman        may       says      plea
# 4   celebrations     begins       term         pm      water      bail
# 5          today      party       love       says         rs     court
# 6         strike      women  sentenced        war    gujarat   accused
# 7      valentine      water        man       help      seeks        sc
# 8       teachers   tomorrow      bandh       indo      delhi     probe
# 9          world   national     normal  terrorism   minister  arrested
# 10      observed  musharraf       make       ties       work       cbi
# 11       another      opens     strike     attack      visit     order
# 12      hawkings    discuss      death      visit         cr  minister
# 13         field      panel       debt    attacks   congress      gets
# 14      children   students       hits  musharraf       plan    notice
# 15        parade    cauvery        way     terror   governor   hearing
# 16        enters   vajpayee     murder   security  officials      jaya
# 17    celebrates      peace       gets    kashmir       take    centre
# 18        beefed      visit       back    support      meets   phoolan
# 19      republic      calls       real   pakistan    project     death
#
# 0     afghan
# 0       cong
# 1      polls
# 2       poll
# 3     leader
# 4    demands
# 5    leaders
# 6        may
# 7      chief
# 8        mla
# 9       back
# 10       ncp
# 11        up
# 12      modi
# 13      says
# 14     rally
# 15      list
# 16  minister
# 17       cpm
# 18        sp
# 19       tdp
