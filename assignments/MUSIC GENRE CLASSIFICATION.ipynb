# %%
import os
import librosa
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
filepath="D:\genres_original"
files=os.listdir(filepath)

# %%
files
# Out:
# ['blues',
#  'classical',
#  'country',
#  'disco',
#  'hiphop',
#  'jazz',
#  'metal',
#  'pop',
#  'reggae',
#  'rock']

# %% [markdown]
# # VEIWING DATA

# %%
for f in files:
    pass

# %%
data=pd.read_csv("features_3_sec.csv")
data
# Out:
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989   rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
# ...

# %%
data=data.drop("filename",axis=1)

# %%
data
# Out:
#       length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0      66149          0.335406         0.091048  0.130405  0.003521
# 1      66149          0.343065         0.086147  0.112699  0.001450
# 2      66149          0.346815         0.092243  0.132003  0.004620
# 3      66149          0.363639         0.086856  0.132565  0.002448
# 4      66149          0.335579         0.088129  0.143289  0.001701
# ...      ...               ...              ...       ...       ...
# 9985   66149          0.349126         0.080515  0.050019  0.000097
# 9986   66149          0.372564         0.082626  0.057897  0.000088
# 9987   66149          0.347481         0.089019  0.052403  0.000701
# 9988   66149          0.387527         0.084815  0.066430  0.000320
# 9989   66149          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# ...

# %%
genre_list = data.iloc[:, -1]
encoder = LabelEncoder()

# %%
genre_list
# Out:
# 0       blues
# 1       blues
# 2       blues
# 3       blues
# 4       blues
#         ...
# 9985     rock
# 9986     rock
# 9987     rock
# 9988     rock
# 9989     rock
# Name: label, Length: 9990, dtype: object

# %%
y = encoder.fit_transform(genre_list)

# %%
y
# Out:
# array([0, 0, 0, ..., 9, 9, 9])

# %%
def one_hot(y):
    y_one_hot = np.zeros((y.shape[0],10))
    for i in range(y.shape[0]):
        index =y[i]
        y_one_hot[i,index] = 1
    return y_one_hot

# %%
y=one_hot(y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))
X.shape
# Out:
# (9990, 58)

# %%
X=X.reshape(X.shape[0],1,X.shape[1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers import Dense
from keras.optimizers import Adam

# %%
X_train=X_train.reshape(6693,1,58)
#y_train=y_train.reshape(6693,1)
X_train.shape,y_train.shape
# Out:
# ((6693, 1, 58), (6693, 10))

# %%
model = Sequential()
model.add(LSTM(units=128, dropout=0.05, recurrent_dropout=0.35, return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(LSTM(units=32,  dropout=0.05, recurrent_dropout=0.35, return_sequences=False))
model.add(Dense(units=y_train.shape[1], activation="softmax"))
opt = Adam()
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_17 (LSTM)               (None, 1, 128)            95744
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 32)                20608
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                330
# ...
# Total params: 116,682
# Trainable params: 116,682
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train,
    y_train,
    epochs=num_epochs,
)
# Out:
# Epoch 1/40
# 210/210 [==============================] - 6s 4ms/step - loss: 1.9589 - accuracy: 0.3701
# Epoch 2/40
# 210/210 [==============================] - 1s 5ms/step - loss: 1.0565 - accuracy: 0.6426
# Epoch 3/40
# 210/210 [==============================] - 1s 5ms/step - loss: 0.7992 - accuracy: 0.7310
# Epoch 4/40
# 210/210 [==============================] - 1s 5ms/step - loss: 0.6762 - accuracy: 0.7802
# Epoch 5/40
# 210/210 [==============================] - 1s 5ms/step - loss: 0.5814 - accuracy: 0.8099
# Epoch 6/40
# 210/210 [==============================] - 1s 6ms/step - loss: 0.5454 - accuracy: 0.8178
# Epoch 7/40
# 210/210 [==============================] - 1s 4ms/step - loss: 0.4938 - accuracy: 0.8281
# Epoch 8/40
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4231 - accuracy: 0.8561
# Epoch 9/40
# 210/210 [==============================] - 1s 6ms/step - loss: 0.4077 - accuracy: 0.8683
# Epoch 10/40
# ...

# %%
score, accuracy = model.evaluate(
    X_test,y_test, batch_size=35, verbose=1
)
print("Test loss:  ", score)
print("Test accuracy:  ", accuracy)
# Out:
# 95/95 [==============================] - 1s 2ms/step - loss: 0.4010 - accuracy: 0.8963
# Test loss:   0.4010418951511383
# Test accuracy:   0.8962693214416504
